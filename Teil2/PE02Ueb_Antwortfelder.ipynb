# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Antwortfeld zu Aufgabe 1
def exEuler(f,t,y0):
    ...
    return t,y

# %%
# Antwortfeld zu Präsenzaufgabe 2
# Erweiterter Plot mit exEuler-Lösungen:

# %% [markdown]
# ---

# %%
# Antwortfeld zu Aufgabe 4
def Heun(f,g,t,x0,y0):
    ...
    return y

# %%
# Antwortfeld zu Aufgabe 5
# Plot mit numerischen Lösungen Heun gegen t und y_Heun gegen t:

# %%
# Antwortfeld zu Aufgabe 6
# Phasenportrait der Heun-Lösungen
